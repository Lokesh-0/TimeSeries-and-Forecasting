# %%
import pandas as pd
import datetime

# %%
df = pd.read_csv("/Users/lokeshreddy/Downloads/cc.csv")

# %%
df
# Out:
#           Timestamp      Open      High       Low     Close  Volume_(BTC)  \
# 0        1325317920      4.39      4.39      4.39      4.39      0.455581
# 1        1325317980       NaN       NaN       NaN       NaN           NaN
# 2        1325318040       NaN       NaN       NaN       NaN           NaN
# 3        1325318100       NaN       NaN       NaN       NaN           NaN
# 4        1325318160       NaN       NaN       NaN       NaN           NaN
# ...             ...       ...       ...       ...       ...           ...
# 4727772  1609372560  28801.47  28829.42  28785.64  28829.42      0.965221
# 4727773  1609372620  28829.42  28863.90  28829.42  28857.06      2.368831
# 4727774  1609372680  28850.49  28900.52  28850.49  28882.82      2.466590
# 4727775  1609372740  28910.54  28911.52  28867.60  28881.30      7.332773
# 4727776  1609372800  28893.21  28928.49  28893.21  28928.49      5.757679
#
#          Volume_(Currency)  Weighted_Price
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4727777 entries, 0 to 4727776
# Data columns (total 8 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   Timestamp          int64
#  1   Open               float64
#  2   High               float64
#  3   Low                float64
#  4   Close              float64
#  5   Volume_(BTC)       float64
#  6   Volume_(Currency)  float64
#  7   Weighted_Price     float64
# dtypes: float64(7), int64(1)
# memory usage: 288.6 MB

# %%
df['Timestamp'] = pd.to_datetime(df['Timestamp'],unit='s')

# %%
df.Timestamp
# Out:
# 0         2011-12-31 07:52:00
# 1         2011-12-31 07:53:00
# 2         2011-12-31 07:54:00
# 3         2011-12-31 07:55:00
# 4         2011-12-31 07:56:00
#                   ...
# 4727772   2020-12-30 23:56:00
# 4727773   2020-12-30 23:57:00
# 4727774   2020-12-30 23:58:00
# 4727775   2020-12-30 23:59:00
# 4727776   2020-12-31 00:00:00
# Name: Timestamp, Length: 4727777, dtype: datetime64[ns]

# %%
df.isnull().sum()
# Out:
# Timestamp                  0
# Open                 1243472
# High                 1243472
# Low                  1243472
# Close                1243472
# Volume_(BTC)         1243472
# Volume_(Currency)    1243472
# Weighted_Price       1243472
# dtype: int64

# %%
df['Volume_(BTC)'].fillna(method='ffill', inplace=True)
df['Volume_(Currency)'].fillna(method='ffill', inplace = True)
df['Weighted_Price'].fillna(method='ffill', inplace= True)
df['Open'].fillna(method='ffill', inplace = True)
df['High'].fillna(method='ffill', inplace = True)
df['Low'].fillna(method='ffill', inplace = True)
df['Close'].fillna(method='ffill', inplace = True)

# %%
df.isnull().sum()
# Out:
# Timestamp            0
# Open                 0
# High                 0
# Low                  0
# Close                0
# Volume_(BTC)         0
# Volume_(Currency)    0
# Weighted_Price       0
# dtype: int64

# %%
df.describe()
# Out:
#                Open          High           Low         Close  Volume_(BTC)  \
# count  4.727777e+06  4.727777e+06  4.727777e+06  4.727777e+06  4.727777e+06
# mean   3.491812e+03  3.494102e+03  3.489388e+03  3.491788e+03  9.551833e+00
# std    4.528839e+03  4.532111e+03  4.525350e+03  4.528821e+03  3.098517e+01
# min    3.800000e+00  3.800000e+00  1.500000e+00  1.500000e+00  0.000000e+00
# 25%    2.408600e+02  2.409600e+02  2.407400e+02  2.408600e+02  3.951785e-01
# 50%    6.558400e+02  6.560000e+02  6.554700e+02  6.559000e+02  1.977690e+00
# 75%    6.757900e+03  6.761710e+03  6.753390e+03  6.757950e+03  7.590467e+00
# max    2.899738e+04  2.901032e+04  2.896366e+04  2.899738e+04  5.853852e+03
#
#        Volume_(Currency)  Weighted_Price
# count       4.727777e+06    4.727777e+06
# mean        2.477606e+04    3.491788e+03
# std         9.800958e+04    4.528823e+03
# min         0.000000e+00    3.800000e+00
# 25%         1.336235e+02    2.408400e+02
# ...

# %%
df['Timestamp']= pd.to_datetime(df['Timestamp'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4727777 entries, 0 to 4727776
# Data columns (total 8 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   Timestamp          datetime64[ns]
#  1   Open               float64
#  2   High               float64
#  3   Low                float64
#  4   Close              float64
#  5   Volume_(BTC)       float64
#  6   Volume_(Currency)  float64
#  7   Weighted_Price     float64
# dtypes: datetime64[ns](1), float64(7)
# memory usage: 288.6 MB

# %%
#innterval dates from first to last 
f = datetime.datetime(2011,12,31,7,52,0)
l = datetime.datetime(2020,12,31,0,0,0)

# %%
week = df[(df['Timestamp']>=f) & (df['Timestamp']<= l)].groupby([pd.Grouper(key="Timestamp", freq = 'W-MON')]).first().reset_index()

# %%
week
# Out:
#      Timestamp      Open      High       Low     Close  Volume_(BTC)  \
# 0   2012-01-02      4.39      4.39      4.39      4.39      0.455581
# 1   2012-01-09      5.00      5.00      5.00      5.00     19.048000
# 2   2012-01-16      6.30      6.30      6.30      6.30      1.000000
# 3   2012-01-23      7.10      7.10      7.10      7.10      0.367445
# 4   2012-01-30      6.52      6.52      6.52      6.52     24.417178
# ..         ...       ...       ...       ...       ...           ...
# 466 2020-12-07  19703.53  19731.24  19695.00  19731.24      2.940703
# 467 2020-12-14  19183.13  19207.73  19182.98  19206.06      2.767272
# 468 2020-12-21  19274.33  19288.48  19274.33  19288.48      2.204310
# 469 2020-12-28  22750.07  22784.44  22750.07  22780.44      1.493160
# 470 2021-01-04  27037.90  27067.42  27027.12  27027.12      2.282142
#
#      Volume_(Currency)  Weighted_Price
# 0             2.000000        4.390000
# 1            95.240000        5.000000
# ...

# %%
df1 = week.reset_index()['Open']
df1
# Out:
# 0          4.39
# 1          5.00
# 2          6.30
# 3          7.10
# 4          6.52
#          ...
# 466    19703.53
# 467    19183.13
# 468    19274.33
# 469    22750.07
# 470    27037.90
# Name: Open, Length: 471, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.plot(df1)

# %%
df2 = df.reset_index()['Open']
plt.plot(df2)

# %%
df3 = week.reset_index()['Close']
plt.plot(df3)

# %%
df4 = df.reset_index()['Close']
plt.plot(df4)

# %%
df5 = week.reset_index()['Weighted_Price']
plt.plot(df5)

# %%
df6 = df.reset_index()['Weighted_Price']
plt.plot(df6)

# %%
df7 = week.reset_index()['Volume_(Currency)']
plt.plot(df7)

# %%
df8 = df.reset_index()['Volume_(Currency)']
plt.plot(df8)

# %%
a = week.plot(kind = 'scatter', x='Weighted_Price', y ='Volume_(BTC)', color = 'black')
a

# %%
a1 = df.plot(kind = 'scatter', x='Weighted_Price', y ='Volume_(BTC)', color = 'black')
a1

# %%
plt.figure(figsize=[14,6])
plt.title('Weighted price by Minutes')
plt.xlabel('Minutes')
plt.ylabel('Weighted Price')
plt.plot(df.Weighted_Price,'_', label='Minutes',color='black')

# %%
h = df[(df['Timestamp']>=f) & (df['Timestamp']<= l)].groupby([pd.Grouper(key="Timestamp", freq = 'H')]).first().reset_index()
h
# Out:
#                 Timestamp      Open      High       Low     Close  \
# 0     2011-12-31 07:00:00      4.39      4.39      4.39      4.39
# 1     2011-12-31 08:00:00      4.39      4.39      4.39      4.39
# 2     2011-12-31 09:00:00      4.39      4.39      4.39      4.39
# 3     2011-12-31 10:00:00      4.39      4.39      4.39      4.39
# 4     2011-12-31 11:00:00      4.39      4.39      4.39      4.39
# ...                   ...       ...       ...       ...       ...
# 78901 2020-12-30 20:00:00  28807.89  28830.00  28768.13  28827.23
# 78902 2020-12-30 21:00:00  28789.77  28808.04  28673.31  28783.67
# 78903 2020-12-30 22:00:00  28896.96  28925.51  28896.96  28907.59
# 78904 2020-12-30 23:00:00  28731.27  28756.10  28714.03  28728.12
# 78905 2020-12-31 00:00:00  28893.21  28928.49  28893.21  28928.49
#
#        Volume_(BTC)  Volume_(Currency)  Weighted_Price
# 0          0.455581       2.000000e+00        4.390000
# 1          0.455581       2.000000e+00        4.390000
# ...

# %%
plt.figure(figsize=[14,6])
plt.title('Weighted price by Hours')
plt.xlabel('Hours')
plt.ylabel('Weighted Price')
plt.plot(h.Weighted_Price,'-', label='Minutes',color='black')

# %% [markdown]
# # Forecasting Using ARIMA

# %%
import statsmodels.api as sm
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
df.sort_index(inplace=True)
h.sort_index(inplace=True)
week.sort_index(inplace=True)

# %%
m = df[(df['Timestamp']>=f) & (df['Timestamp']<= l)].groupby([pd.Grouper(key="Timestamp", freq = 'M')]).first().reset_index()
m
# Out:
#      Timestamp      Open      High       Low     Close  Volume_(BTC)  \
# 0   2011-12-31      4.39      4.39      4.39      4.39      0.455581
# 1   2012-01-31      4.58      4.58      4.58      4.58      9.000000
# 2   2012-02-29      5.30      5.30      5.30      5.30      1.000000
# 3   2012-03-31      4.99      4.99      4.99      4.99      1.000000
# 4   2012-04-30      4.90      4.90      4.90      4.90      4.393736
# ..         ...       ...       ...       ...       ...           ...
# 104 2020-08-31  11357.98  11375.78  11357.98  11375.78      5.268972
# 105 2020-09-30  11658.48  11670.04  11658.44  11663.60     17.507289
# 106 2020-10-31  10780.83  10790.79  10780.83  10783.78      2.946380
# 107 2020-11-30  13799.44  13799.44  13715.64  13738.59      9.481311
# 108 2020-12-31  19703.53  19731.24  19695.00  19731.24      2.940703
#
#      Volume_(Currency)  Weighted_Price
# 0             2.000000        4.390000
# 1            41.220000        4.580000
# ...

# %%
plt.figure(figsize=[14,6])
plt.title('Weighted price by Months')
plt.xlabel('Monthly')
plt.ylabel('Weighted Price')
plt.plot(m.Weighted_Price,'-', label='Monthly',color='black')

# %% [markdown]
# # Time Series Decomposition

# %%
result_add = seasonal_decompose(x=week['Weighted_Price'], model='additive', extrapolate_trend='freq', period=2)
plt.rcParams.update({'figure.figsize': (20,8)})
result_add.plot().suptitle('Additive Decompose', fontsize=25)
plt.show()

# %%
result_add = seasonal_decompose(x=m['Weighted_Price'], model='multiplicative', extrapolate_trend='freq', period=2)
plt.rcParams.update({'figure.figsize': (20,8)})
result_add.plot().suptitle('multiplicative Decompose', fontsize=25)
plt.show()

# %% [markdown]
# # Rolling Mean and Standard Deviation

# %%
RollingMean = m['Weighted_Price'].rolling(window = 12).mean()
RollingSTD = m['Weighted_Price'].rolling(window = 12).std()
print(RollingMean)
print(RollingSTD)
# Out:
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
#            ...
# 104     8719.687003
# 105     8892.420573
# 106     9098.433127
# 107     9482.350029
# 108    10495.630628
# Name: Weighted_Price, Length: 109, dtype: float64
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
#           ...
# 104    1288.958758
# 105    1532.571058
# 106    1611.674352
# 107    2101.466842
# 108    3532.507272
# Name: Weighted_Price, Length: 109, dtype: float64

# %%
actual = plt.plot(m['Weighted_Price'], color = 'green', label='Actual')
mean = plt.plot(RollingMean, color = 'black', label='Mean')
std = plt.plot(RollingSTD, color = 'red', label='STD')
plt.legend(loc='best')
plt.title('Mean and STD')
plt.xlabel('Months')
plt.ylabel('Weighted Price')
plt.show()

# %% [markdown]
# # Dickey-Fuller Test

# %%
from statsmodels.tsa.stattools import adfuller
test = adfuller(m['Weighted_Price'], autolag='AIC') 

result = pd.Series(test[0:4], index=['Dickey Fuller test Statistic:','P-Value:','Lags Used:','No. Of observations:'])
for key,value in test[4].items():
    result['Critical Value: %s' %key] = value
print(result)
# Out:
# Dickey Fuller test Statistic:      0.898264
# P-Value:                           0.993068
# Lags Used:                         0.000000
# No. Of observations:             108.000000
# Critical Value: 1%                -3.492401
# Critical Value: 5%                -2.888697
# Critical Value: 10%               -2.581255
# dtype: float64

# %% [markdown]
# We can see the P-Value is 0.993068, we cant reject the null hypothesis so the data is not stationary

# %%
import numpy as np
m_log = np.log(m['Weighted_Price'])
plt.plot(m_log)

# %%
RMean = np.log(m['Weighted_Price']).rolling(window = 12).mean()
plt.plot(m_log)
plt.plot(RMean)

# %% [markdown]
# Tried by taking the log for the weighted price but the results are not stationary yet but had some improvement in the mean compared to the last graph

# %%
m['initial Diff']= m['Weighted_Price'] - m['Weighted_Price'].shift(12)

# %%
m
# Out:
#      Timestamp      Open      High       Low     Close  Volume_(BTC)  \
# 0   2011-12-31      4.39      4.39      4.39      4.39      0.455581
# 1   2012-01-31      4.58      4.58      4.58      4.58      9.000000
# 2   2012-02-29      5.30      5.30      5.30      5.30      1.000000
# 3   2012-03-31      4.99      4.99      4.99      4.99      1.000000
# 4   2012-04-30      4.90      4.90      4.90      4.90      4.393736
# ..         ...       ...       ...       ...       ...           ...
# 104 2020-08-31  11357.98  11375.78  11357.98  11375.78      5.268972
# 105 2020-09-30  11658.48  11670.04  11658.44  11663.60     17.507289
# 106 2020-10-31  10780.83  10790.79  10780.83  10783.78      2.946380
# 107 2020-11-30  13799.44  13799.44  13715.64  13738.59      9.481311
# 108 2020-12-31  19703.53  19731.24  19695.00  19731.24      2.940703
#
#      Volume_(Currency)  Weighted_Price  initial Diff
# 0             2.000000        4.390000           NaN
# ...

# %%
test = adfuller(m['initial Diff'].dropna(), autolag='AIC') 

result = pd.Series(test[0:4], index=['Dickey Fuller test Statistic:','P-Value:','Lags Used:','No. Of observations:'])
print(result)
# Out:
# Dickey Fuller test Statistic:    -0.702116
# P-Value:                          0.846201
# Lags Used:                       12.000000
# No. Of observations:             84.000000
# dtype: float64

# %%
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf
from itertools import product
import warnings

# %%
fig = plt.figure(figsize=(20,8))
ax1 = fig.add_subplot(211)
fig= sm.graphics.tsa.plot_acf(m['initial Diff'].iloc[13:],lags=40, ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(m['initial Diff'].iloc[13:], lags = 50, ax=ax2)

# %%
from statsmodels.tsa.arima_model import ARIMA

# %%
Qs = range(0, 2)
qs = range(0, 4)
Ps = range(0, 4)
ps = range(0, 2)
D=1
d=1
parameters = product(ps, qs, Ps, Qs) #SARIMAX model Parameters:(p,d,q)(sp,sd,sq,s) +exog
parameterslist = list(parameters)
len(parameterslist)
results = []
bestaic = float("inf")
warnings.filterwarnings("ignore")
for param in parameterslist:
    try:
        model=sm.tsa.statespace.SARIMAX(m.Weighted_Price, order=(param[0], d, param[1]),seasonal_order=(param[2],D, param[3],12),enforce_stationarity=False,enforce_invertibility=False).fit(disp=-1)
    except ValueError:
        continue
    aic = model.aic
    if aic < bestaic:
        model1 = model
        aic1 = aic
        param1 = param
    results.append([param, model.aic])

# %%
result = pd.DataFrame(results)
result.columns = ['parameters', 'aic']
print(result.sort_values(by = 'aic', ascending=True).head())
print(model1.summary())
# Out:
#       parameters          aic
# 38  (1, 0, 3, 0)  1036.879402
# 46  (1, 1, 3, 0)  1038.694475
# 39  (1, 0, 3, 1)  1038.879155
# 54  (1, 2, 3, 0)  1039.241341
# 47  (1, 1, 3, 1)  1040.488103
#                                       SARIMAX Results
# ...
# Dep. Variable:                       Weighted_Price   No. Observations:                  109
# Model:             SARIMAX(1, 1, 3)x(3, 1, [1], 12)   Log Likelihood                -514.457
# Date:                              Fri, 15 Jan 2021   AIC                           1046.913
# Time:                                      02:01:31   BIC                           1065.611
# Sample:                                           0   HQIC                          1054.212
#                                               - 109
# Covariance Type:                                opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
residual = model.resid
fig = plt.figure(figsize=(20,8))
ax1 = fig.add_subplot(211)
fig= sm.graphics.tsa.plot_acf(residual,lags=50, ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(residual, lags = 50, ax=ax2)

# %%
model.plot_diagnostics(figsize=(15, 12))

# %%
fig = plt.figure(figsize=(20,8))
model1.resid.plot()
fig.suptitle('Residual Plot of the Best Model')
test1 = adfuller(model1.resid, autolag='AIC') 
result1 = pd.Series(test1[0:4], index=['Dickey Fuller test Statistic:','P-Value:','Lags Used:','No. Of observations:'])
print(result1)
# Out:
# Dickey Fuller test Statistic:   -9.567665e+00
# P-Value:                         2.333480e-16
# Lags Used:                       0.000000e+00
# No. Of observations:             1.080000e+02
# dtype: float64

# %%
month_p = m[['Weighted_Price']]
upcoming = pd.DataFrame()
month_p = pd.concat([month_p,upcoming])
month_p['forecast'] = model1.predict(start=0, end=110)
plt.figure(figsize=(20,8))
plt.title('Bitcoin Predicted vs Actual')
plt.xlabel('Months')
plt.ylabel('USD')
month_p.Weighted_Price.plot()
month_p.forecast.plot(color='black', ls='-', label='Predicted Weighted_Price')
plt.show()

# %% [markdown]
# #Will add few more models (LSTM, Facebook Prophet, Garch and few more models and compare)
